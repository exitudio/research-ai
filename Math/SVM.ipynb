# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_p = np.array([[1,3], [1,4], [2,5], [3,6]])
x_n = np.array([[4,3],[ 5,3],[6,4], [7,5]])
plt.scatter(*zip(*x_p))
plt.scatter(*zip(*x_n))

# %%
x = np.linspace(0,10)
y = -1/2*x + 5
data = [4,3]
plt.plot(x, y)
plt.scatter(*data)

# %%
# ax + by + c = 0
# y = -(a/b)x - c/b

# y = s1*x - s0
# s1 = -a/b
# s0 = -c/b
# assume:::
# a = 1
# b = 2
# c = -10
