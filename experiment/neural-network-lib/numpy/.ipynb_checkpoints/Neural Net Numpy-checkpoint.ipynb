# %% [markdown]
# ### Raw NN
# [https://towardsdatascience.com/how-to-build-your-own-neural-network-from-scratch-in-python-68998a08e4f6](https://towardsdatascience.com/how-to-build-your-own-neural-network-from-scratch-in-python-68998a08e4f6)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from exit import NeuralNetwork
from exit.layers import Dense
from exit.activations import Sigmoid, Relu
from exit.losses import Cross_entropy, L2
from exit.optimizers import Momentum, RMS_prop, Adam

# %% [markdown]
# ### Regression

# %%
nn = NeuralNetwork()
input = np.linspace(0,20,21).reshape(-1,1)
output = (input*2+10)
nn.sequence(
    input.shape[1],
    Dense(4, Relu),
    Dense(1),
)
for i in range(100):
    predict = nn.train(input, output, L2, learning_rate=0.00003)
    if i%99 is 0:
        print(f'loss {i} :', predict['loss'])
# Out:
# loss 0 : 8533.20379604187
# loss 99 : 16.2958018188015

# %%
plt.plot(input, output)
plt.plot(input, nn.predict(input))

# %%
nn = NeuralNetwork(Adam())

input = np.arange(-100,100).reshape(-1, 1)
output = np.power(input, 2) - 5

nn.sequence(
    input.shape[1],
    Dense(6, Relu),
    Dense(1),
)
for i in range(1000):
    predict = nn.train(input, output, L2, learning_rate=0.1)
    if i%99 is 0:
        print(f'loss {i} :', predict['loss'])

plt.plot(input, output)
plt.plot(input, nn.predict(input))
# Out:
# loss 0 : 19721692.16993105
# loss 99 : 1096786.35779509
# loss 198 : 850532.5417980105
# loss 297 : 570231.574446146
# loss 396 : 341926.8337926839
# loss 495 : 205827.72453971472
# loss 594 : 134918.52602739923
# loss 693 : 95311.51070213881
# loss 792 : 66304.19030915177
# loss 891 : 49945.93643809231
# loss 990 : 39930.775964656

# %%
for i in range(nn.network[0]._weights.shape[1]): 
    w = nn.network[0]._weights[0, i]
    b = nn.network[0]._bias[0, i]
# Out:
# -5.801966610934791
# -1.7012063978532386
# 5.531742740346989
# -2.0608861046329663
# 1.901399036449888
# 2.0120641842512175

# %% [markdown]
# ### Classifiaction

# %%
nn = NeuralNetwork()
input = np.linspace(0,20,100).reshape(-1,1)
output = (input*2+10 > 30).astype(int)
nn.sequence(
    input.shape[1],
    Dense(1, Sigmoid),
)
for i in range(1000):
    predict = nn.train(input, output, Cross_entropy, learning_rate=0.01)
    if i%99 is 0:
        print(f'loss: {i} = ', predict['loss'])
# Out:
# loss: 0 =  0.6164529785862135
# loss: 99 =  5.599929532793836
# loss: 198 =  0.1281506032539912
# loss: 297 =  0.7621372406112745
# loss: 396 =  0.20808174432820156
# loss: 495 =  0.2766486753920611
# loss: 594 =  0.1147087053102106
# loss: 693 =  0.10771252804116271
# loss: 792 =  0.059916717684150786
# loss: 891 =  0.04612496351354095
# loss: 990 =  0.034870491116717375

# %%
plt.plot(input, output)
plt.plot(input, nn.predict(input))

# %%
x = np.random.randn(100000)*2 + 10
mean = np.mean(x)
sd = np.sqrt(np.sum( np.square(x-mean) ) / (x.shape[0]-1)  )
sd, mean
# Out:
# (1.9961660131106007, 10.005951167629597)

# %%
import math
x = np.linspace(-5, 5, 200)

def normal_distribution(mu, sd):
    return 1/ np.sqrt(2*math.pi*np.square(sd)) * np.power(math.e, -np.square(x-mu)/ (2*np.square(sd)))

y = normal_distribution(0, 0.2)
# plt.plot(x, y1)

# %%
y = np.random.randn(10000)
x = np.linspace(0,999, 10000)
h = plt.hist(y, 100)
