# %%
import pandas as pd
diabetes = pd.read_csv('pima-indians-diabetes.csv')
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### normalize

# %%
# we can use sklearn but in this case teacher want to show trick in pandas
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max()-x.min()))
diabetes[cols_to_norm].head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree
# 0  0.500745  0.234415
# 1  0.396423  0.116567
# 2  0.347243  0.253629
# 3  0.418778  0.038002
# 4  0.642325  0.943638

# %% [markdown]
# ### Clean up data

# %%
import tensorflow as tf
cols = list(diabetes.drop('Group',axis=1) \
                    .drop('Class',axis=1) \
                    .drop('Age',axis=1)
                    .columns)
feat_cols = []
for c in cols:
    feat_cols.append(tf.feature_column.numeric_column(c))

# Group
group_names = list(diabetes.groupby('Group').groups.keys()) # ['A','B','C','D']
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',group_names)
feat_cols.append(assigned_group)

# Age [convert to category]
import matplotlib.pyplot as plt
# %matplotlib inline
diabetes['Age'].hist(bins=20)

feature_age = tf.feature_column.numeric_column('Age')
age_buckets = tf.feature_column.bucketized_column(feature_age,boundaries=[20,30,40,50,60,70,80])
feat_cols.append(age_buckets)

# %% [markdown]
# ### Train test split

# %%
x_data = diabetes.drop('Class',axis=1)
labels = diabetes['Class']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_data, labels, test_size=0.33, random_state=101)

# %% [markdown]
# # Linear Classification
# ### 1. Train

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,
                                                y=y_train,
                                                batch_size=10,
                                                num_epochs=1000,
                                                shuffle=True)
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sr/9k0jqkfs33q22ppyt_t7yjt9716826/T/tmpxjjzed6k
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_tf_random_seed': 1, '_save_checkpoints_steps': None, '_log_step_count_steps': 100, '_session_config': None, '_model_dir': '/var/folders/sr/9k0jqkfs33q22ppyt_t7yjt9716826/T/tmpxjjzed6k', '_keep_checkpoint_max': 5, '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sr/9k0jqkfs33q22ppyt_t7yjt9716826/T/tmpxjjzed6k/model.ckpt.
# INFO:tensorflow:step = 1, loss = 6.93147
# INFO:tensorflow:global_step/sec: 346.694
# INFO:tensorflow:step = 101, loss = 6.28816 (0.289 sec)
# INFO:tensorflow:global_step/sec: 366.314
# INFO:tensorflow:step = 201, loss = 4.25209 (0.273 sec)
# INFO:tensorflow:global_step/sec: 369.291
# INFO:tensorflow:step = 301, loss = 4.42884 (0.271 sec)
# INFO:tensorflow:global_step/sec: 392.916
# INFO:tensorflow:step = 401, loss = 6.16949 (0.255 sec)
# INFO:tensorflow:global_step/sec: 367.647
# INFO:tensorflow:step = 501, loss = 5.37632 (0.272 sec)
# INFO:tensorflow:global_step/sec: 393.334
# INFO:tensorflow:step = 601, loss = 6.52036 (0.254 sec)
# INFO:tensorflow:global_step/sec: 394.577
# INFO:tensorflow:step = 701, loss = 6.42817 (0.253 sec)
# INFO:tensorflow:global_step/sec: 370.55
# INFO:tensorflow:step = 801, loss = 4.27347 (0.270 sec)
# INFO:tensorflow:global_step/sec: 370.678
# INFO:tensorflow:step = 901, loss = 3.32318 (0.270 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/sr/9k0jqkfs33q22ppyt_t7yjt9716826/T/tmpxjjzed6k/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.93591.

# %% [markdown]
# ### 2. Evaluate [Test]

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)
result = model.evaluate(eval_input_func)
result
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-03-17-19:45:34
# INFO:tensorflow:Restoring parameters from /var/folders/sr/9k0jqkfs33q22ppyt_t7yjt9716826/T/tmpxjjzed6k/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2018-03-17-19:45:35
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.728346, accuracy_baseline = 0.65748, auc = 0.78746, auc_precision_recall = 0.622362, average_loss = 0.529196, global_step = 1000, label/mean = 0.34252, loss = 5.16984, prediction/mean = 0.351259
# {'accuracy': 0.72834647,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.78745961,
#  'auc_precision_recall': 0.6223619,
#  'average_loss': 0.52919602,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 5.169838,
#  'prediction/mean': 0.35125944}

# %% [markdown]
# ### 3. Prediction

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
    x=X_test,
    batch_size=10,
    num_epochs=1,
    shuffle=False
)
predictions = model.predict(pred_input_func)
list(predictions)
# Out:
# INFO:tensorflow:Restoring parameters from /var/folders/sr/9k0jqkfs33q22ppyt_t7yjt9716826/T/tmpxjjzed6k/model.ckpt-1000
# [{'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50331974], dtype=float32),
#   'logits': array([ 0.0132792], dtype=float32),
#   'probabilities': array([ 0.49668026,  0.50331974], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59265697], dtype=float32),
#   'logits': array([ 0.37495995], dtype=float32),
#   'probabilities': array([ 0.40734309,  0.59265697], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35350305], dtype=float32),
#   'logits': array([-0.60367644], dtype=float32),
#   'probabilities': array([ 0.64649695,  0.35350305], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.31628716], dtype=float32),
#   'logits': array([-0.77088749], dtype=float32),
#   'probabilities': array([ 0.68371284,  0.31628713], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1344763], dtype=float32),
#   'logits': array([-1.8619467], dtype=float32),
#   'probabilities': array([ 0.8655237,  0.1344763], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.70047891], dtype=float32),
#   'logits': array([ 0.84957933], dtype=float32),
#   'probabilities': array([ 0.29952112,  0.70047891], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55838406], dtype=float32),
#   'logits': array([ 0.23460639], dtype=float32),
#   'probabilities': array([ 0.44161597,  0.55838406], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.31543848], dtype=float32),
#   'logits': array([-0.77481484], dtype=float32),
#   'probabilities': array([ 0.68456155,  0.31543848], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22972314], dtype=float32),
#   'logits': array([-1.20987511], dtype=float32),
#   'probabilities': array([ 0.7702769 ,  0.22972317], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22306056], dtype=float32),
#   'logits': array([-1.24791908], dtype=float32),
#   'probabilities': array([ 0.77693945,  0.22306058], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12081137], dtype=float32),
#   'logits': array([-1.98476899], dtype=float32),
#   'probabilities': array([ 0.87918866,  0.12081138], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14334615], dtype=float32),
#   'logits': array([-1.7877717], dtype=float32),
#   'probabilities': array([ 0.85665387,  0.14334613], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26045999], dtype=float32),
#   'logits': array([-1.0435791], dtype=float32),
#   'probabilities': array([ 0.73953998,  0.26045999], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54842997], dtype=float32),
#   'logits': array([ 0.19432902], dtype=float32),
#   'probabilities': array([ 0.45157009,  0.54842997], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16560985], dtype=float32),
#   'logits': array([-1.61706638], dtype=float32),
#   'probabilities': array([ 0.83439016,  0.16560985], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33410135], dtype=float32),
#   'logits': array([-0.68969309], dtype=float32),
#   'probabilities': array([ 0.66589868,  0.33410135], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.36551023], dtype=float32),
#   'logits': array([-0.55152696], dtype=float32),
#   'probabilities': array([ 0.63448977,  0.3655102 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11982094], dtype=float32),
#   'logits': array([-1.9941268], dtype=float32),
#   'probabilities': array([ 0.88017905,  0.11982095], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32856393], dtype=float32),
#   'logits': array([-0.71468735], dtype=float32),
#   'probabilities': array([ 0.67143607,  0.32856393], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13128628], dtype=float32),
#   'logits': array([-1.88963342], dtype=float32),
#   'probabilities': array([ 0.86871374,  0.13128628], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20686865], dtype=float32),
#   'logits': array([-1.34390485], dtype=float32),
#   'probabilities': array([ 0.79313141,  0.20686865], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.28994247], dtype=float32),
#   'logits': array([-0.8956635], dtype=float32),
#   'probabilities': array([ 0.7100575 ,  0.28994244], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.63943106], dtype=float32),
#   'logits': array([ 0.57289565], dtype=float32),
#   'probabilities': array([ 0.36056891,  0.63943106], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20328856], dtype=float32),
#   'logits': array([-1.36586607], dtype=float32),
#   'probabilities': array([ 0.79671144,  0.20328857], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17264517], dtype=float32),
#   'logits': array([-1.56699514], dtype=float32),
#   'probabilities': array([ 0.82735479,  0.17264518], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.74946392], dtype=float32),
#   'logits': array([ 1.09575534], dtype=float32),
#   'probabilities': array([ 0.25053605,  0.74946392], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16918257], dtype=float32),
#   'logits': array([-1.59143162], dtype=float32),
#   'probabilities': array([ 0.8308174 ,  0.16918257], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30647373], dtype=float32),
#   'logits': array([-0.81665707], dtype=float32),
#   'probabilities': array([ 0.69352627,  0.30647373], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.09397956], dtype=float32),
#   'logits': array([-2.26598454], dtype=float32),
#   'probabilities': array([ 0.90602046,  0.09397957], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.56357706], dtype=float32),
#   'logits': array([ 0.25569224], dtype=float32),
#   'probabilities': array([ 0.43642294,  0.56357706], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.93381625], dtype=float32),
#   'logits': array([ 2.64684582], dtype=float32),
#   'probabilities': array([ 0.06618367,  0.93381625], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.36734095], dtype=float32),
#   'logits': array([-0.54364127], dtype=float32),
#   'probabilities': array([ 0.63265908,  0.36734095], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30659291], dtype=float32),
#   'logits': array([-0.81609631], dtype=float32),
#   'probabilities': array([ 0.69340706,  0.30659291], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54993773], dtype=float32),
#   'logits': array([ 0.20041895], dtype=float32),
#   'probabilities': array([ 0.45006233,  0.54993773], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23695736], dtype=float32),
#   'logits': array([-1.16943371], dtype=float32),
#   'probabilities': array([ 0.76304257,  0.23695734], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35524765], dtype=float32),
#   'logits': array([-0.59605122], dtype=float32),
#   'probabilities': array([ 0.64475238,  0.35524765], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.48490825], dtype=float32),
#   'logits': array([-0.06038535], dtype=float32),
#   'probabilities': array([ 0.51509172,  0.48490822], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.62290072], dtype=float32),
#   'logits': array([ 0.50187874], dtype=float32),
#   'probabilities': array([ 0.37709925,  0.62290072], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.73917007], dtype=float32),
#   'logits': array([ 1.04165936], dtype=float32),
#   'probabilities': array([ 0.26082996,  0.73917007], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29043779], dtype=float32),
#   'logits': array([-0.89325881], dtype=float32),
#   'probabilities': array([ 0.70956224,  0.29043782], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17195496], dtype=float32),
#   'logits': array([-1.57183504], dtype=float32),
#   'probabilities': array([ 0.82804507,  0.17195496], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49543685], dtype=float32),
#   'logits': array([-0.01825321], dtype=float32),
#   'probabilities': array([ 0.50456315,  0.49543682], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1459849], dtype=float32),
#   'logits': array([-1.76644564], dtype=float32),
#   'probabilities': array([ 0.85401511,  0.1459849 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.48885113], dtype=float32),
#   'logits': array([-0.04460287], dtype=float32),
#   'probabilities': array([ 0.51114887,  0.48885113], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13308831], dtype=float32),
#   'logits': array([-1.87392426], dtype=float32),
#   'probabilities': array([ 0.86691171,  0.13308832], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1015804], dtype=float32),
#   'logits': array([-2.17978668], dtype=float32),
#   'probabilities': array([ 0.89841962,  0.1015804 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59077531], dtype=float32),
#   'logits': array([ 0.36717141], dtype=float32),
#   'probabilities': array([ 0.40922469,  0.59077531], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17467728], dtype=float32),
#   'logits': array([-1.55283439], dtype=float32),
#   'probabilities': array([ 0.82532269,  0.17467725], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19404458], dtype=float32),
#   'logits': array([-1.42394054], dtype=float32),
#   'probabilities': array([ 0.80595541,  0.19404458], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11230028], dtype=float32),
#   'logits': array([-2.0674572], dtype=float32),
#   'probabilities': array([ 0.88769972,  0.11230028], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16100414], dtype=float32),
#   'logits': array([-1.65077567], dtype=float32),
#   'probabilities': array([ 0.83899587,  0.16100414], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23448494], dtype=float32),
#   'logits': array([-1.18315744], dtype=float32),
#   'probabilities': array([ 0.76551503,  0.23448496], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24133545], dtype=float32),
#   'logits': array([-1.14537179], dtype=float32),
#   'probabilities': array([ 0.75866449,  0.24133545], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3377974], dtype=float32),
#   'logits': array([-0.67312515], dtype=float32),
#   'probabilities': array([ 0.6622026 ,  0.33779743], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12285852], dtype=float32),
#   'logits': array([-1.96563482], dtype=float32),
#   'probabilities': array([ 0.87714142,  0.12285851], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21027742], dtype=float32),
#   'logits': array([-1.32325399], dtype=float32),
#   'probabilities': array([ 0.78972262,  0.21027742], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19913919], dtype=float32),
#   'logits': array([-1.3916831], dtype=float32),
#   'probabilities': array([ 0.80086082,  0.19913919], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20539011], dtype=float32),
#   'logits': array([-1.35294008], dtype=float32),
#   'probabilities': array([ 0.7946099 ,  0.20539011], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.46492499], dtype=float32),
#   'logits': array([-0.14053094], dtype=float32),
#   'probabilities': array([ 0.53507507,  0.46492499], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15087682], dtype=float32),
#   'logits': array([-1.72774053], dtype=float32),
#   'probabilities': array([ 0.84912312,  0.15087682], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21854094], dtype=float32),
#   'logits': array([-1.27418947], dtype=float32),
#   'probabilities': array([ 0.78145903,  0.21854091], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.62376857], dtype=float32),
#   'logits': array([ 0.50557482], dtype=float32),
#   'probabilities': array([ 0.37623149,  0.62376857], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.60969645], dtype=float32),
#   'logits': array([ 0.44603646], dtype=float32),
#   'probabilities': array([ 0.39030355,  0.60969645], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.47821149], dtype=float32),
#   'logits': array([-0.08720922], dtype=float32),
#   'probabilities': array([ 0.52178848,  0.47821146], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34928975], dtype=float32),
#   'logits': array([-0.62216264], dtype=float32),
#   'probabilities': array([ 0.65071028,  0.34928977], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.45149446], dtype=float32),
#   'logits': array([-0.1946342], dtype=float32),
#   'probabilities': array([ 0.54850549,  0.45149446], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16857228], dtype=float32),
#   'logits': array([-1.59577978], dtype=float32),
#   'probabilities': array([ 0.83142775,  0.16857229], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18699533], dtype=float32),
#   'logits': array([-1.46965325], dtype=float32),
#   'probabilities': array([ 0.81300467,  0.18699531], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14421201], dtype=float32),
#   'logits': array([-1.78073812], dtype=float32),
#   'probabilities': array([ 0.85578793,  0.14421201], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12299553], dtype=float32),
#   'logits': array([-1.96436417], dtype=float32),
#   'probabilities': array([ 0.87700444,  0.12299552], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.56932795], dtype=float32),
#   'logits': array([ 0.27910972], dtype=float32),
#   'probabilities': array([ 0.43067205,  0.56932795], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22398964], dtype=float32),
#   'logits': array([-1.24256611], dtype=float32),
#   'probabilities': array([ 0.77601033,  0.22398964], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39049557], dtype=float32),
#   'logits': array([-0.44522953], dtype=float32),
#   'probabilities': array([ 0.6095044 ,  0.39049557], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55435234], dtype=float32),
#   'logits': array([ 0.21827173], dtype=float32),
#   'probabilities': array([ 0.44564772,  0.55435234], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29862693], dtype=float32),
#   'logits': array([-0.85384482], dtype=float32),
#   'probabilities': array([ 0.70137304,  0.29862693], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61219591], dtype=float32),
#   'logits': array([ 0.45655203], dtype=float32),
#   'probabilities': array([ 0.38780409,  0.61219591], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11694715], dtype=float32),
#   'logits': array([-2.02166295], dtype=float32),
#   'probabilities': array([ 0.88305283,  0.11694715], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.58710831], dtype=float32),
#   'logits': array([ 0.35202384], dtype=float32),
#   'probabilities': array([ 0.41289175,  0.58710831], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1156537], dtype=float32),
#   'logits': array([-2.03424835], dtype=float32),
#   'probabilities': array([ 0.88434625,  0.11565369], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51480186], dtype=float32),
#   'logits': array([ 0.05922472], dtype=float32),
#   'probabilities': array([ 0.48519814,  0.51480186], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33137143], dtype=float32),
#   'logits': array([-0.70198882], dtype=float32),
#   'probabilities': array([ 0.66862857,  0.33137143], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1540533], dtype=float32),
#   'logits': array([-1.70315778], dtype=float32),
#   'probabilities': array([ 0.84594673,  0.1540533 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52889472], dtype=float32),
#   'logits': array([ 0.11570787], dtype=float32),
#   'probabilities': array([ 0.47110525,  0.52889472], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54989421], dtype=float32),
#   'logits': array([ 0.20024347], dtype=float32),
#   'probabilities': array([ 0.4501057 ,  0.54989421], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52138978], dtype=float32),
#   'logits': array([ 0.08561146], dtype=float32),
#   'probabilities': array([ 0.47861016,  0.52138978], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16054396], dtype=float32),
#   'logits': array([-1.65418637], dtype=float32),
#   'probabilities': array([ 0.83945608,  0.16054396], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32065949], dtype=float32),
#   'logits': array([-0.75074267], dtype=float32),
#   'probabilities': array([ 0.67934048,  0.32065949], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13988829], dtype=float32),
#   'logits': array([-1.81621814], dtype=float32),
#   'probabilities': array([ 0.86011177,  0.1398883 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.69275045], dtype=float32),
#   'logits': array([ 0.8130095], dtype=float32),
#   'probabilities': array([ 0.30724958,  0.69275045], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.81211334], dtype=float32),
#   'logits': array([ 1.46380115], dtype=float32),
#   'probabilities': array([ 0.18788664,  0.81211334], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59617108], dtype=float32),
#   'logits': array([ 0.38953638], dtype=float32),
#   'probabilities': array([ 0.40382892,  0.59617108], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20276903], dtype=float32),
#   'logits': array([-1.36907685], dtype=float32),
#   'probabilities': array([ 0.79723102,  0.20276906], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.41516528], dtype=float32),
#   'logits': array([-0.34265262], dtype=float32),
#   'probabilities': array([ 0.58483475,  0.41516528], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33575329], dtype=float32),
#   'logits': array([-0.6822769], dtype=float32),
#   'probabilities': array([ 0.66424668,  0.33575332], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.42480311], dtype=float32),
#   'logits': array([-0.3030867], dtype=float32),
#   'probabilities': array([ 0.57519692,  0.42480308], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30749956], dtype=float32),
#   'logits': array([-0.81183529], dtype=float32),
#   'probabilities': array([ 0.69250041,  0.30749953], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.42249304], dtype=float32),
#   'logits': array([-0.3125475], dtype=float32),
#   'probabilities': array([ 0.57750696,  0.42249304], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1471037], dtype=float32),
#   'logits': array([-1.75750017], dtype=float32),
#   'probabilities': array([ 0.85289633,  0.14710371], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.53411347], dtype=float32),
#   'logits': array([ 0.1366663], dtype=float32),
#   'probabilities': array([ 0.4658865 ,  0.53411347], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52729118], dtype=float32),
#   'logits': array([ 0.10927343], dtype=float32),
#   'probabilities': array([ 0.47270876,  0.52729118], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22946402], dtype=float32),
#   'logits': array([-1.21134007], dtype=float32),
#   'probabilities': array([ 0.77053601,  0.22946404], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16693191], dtype=float32),
#   'logits': array([-1.6075294], dtype=float32),
#   'probabilities': array([ 0.83306807,  0.1669319 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16607428], dtype=float32),
#   'logits': array([-1.61370921], dtype=float32),
#   'probabilities': array([ 0.83392572,  0.16607428], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26566586], dtype=float32),
#   'logits': array([-1.01672482], dtype=float32),
#   'probabilities': array([ 0.73433411,  0.26566586], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34420213], dtype=float32),
#   'logits': array([-0.64462352], dtype=float32),
#   'probabilities': array([ 0.65579784,  0.3442021 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13012756], dtype=float32),
#   'logits': array([-1.8998313], dtype=float32),
#   'probabilities': array([ 0.86987245,  0.13012758], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.28455511], dtype=float32),
#   'logits': array([-0.92197764], dtype=float32),
#   'probabilities': array([ 0.71544492,  0.28455511], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20866998], dtype=float32),
#   'logits': array([-1.3329612], dtype=float32),
#   'probabilities': array([ 0.79133004,  0.20866996], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.08685161], dtype=float32),
#   'logits': array([-2.35269737], dtype=float32),
#   'probabilities': array([ 0.91314834,  0.0868516 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11595182], dtype=float32),
#   'logits': array([-2.03133678], dtype=float32),
#   'probabilities': array([ 0.88404822,  0.11595182], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.73656309], dtype=float32),
#   'logits': array([ 1.02818108], dtype=float32),
#   'probabilities': array([ 0.26343688,  0.73656309], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.168883], dtype=float32),
#   'logits': array([-1.59356451], dtype=float32),
#   'probabilities': array([ 0.83111703,  0.168883  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12421608], dtype=float32),
#   'logits': array([-1.95309687], dtype=float32),
#   'probabilities': array([ 0.87578392,  0.12421607], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13261352], dtype=float32),
#   'logits': array([-1.87804556], dtype=float32),
#   'probabilities': array([ 0.86738646,  0.13261352], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.46063191], dtype=float32),
#   'logits': array([-0.15779901], dtype=float32),
#   'probabilities': array([ 0.53936809,  0.46063191], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.42246088], dtype=float32),
#   'logits': array([-0.31267935], dtype=float32),
#   'probabilities': array([ 0.57753915,  0.42246088], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2308345], dtype=float32),
#   'logits': array([-1.20360518], dtype=float32),
#   'probabilities': array([ 0.76916546,  0.23083448], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39507458], dtype=float32),
#   'logits': array([-0.4260307], dtype=float32),
#   'probabilities': array([ 0.60492545,  0.39507458], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17780659], dtype=float32),
#   'logits': array([-1.53127933], dtype=float32),
#   'probabilities': array([ 0.82219344,  0.17780659], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21827744], dtype=float32),
#   'logits': array([-1.27573299], dtype=float32),
#   'probabilities': array([ 0.78172261,  0.21827744], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49538484], dtype=float32),
#   'logits': array([-0.01846123], dtype=float32),
#   'probabilities': array([ 0.50461519,  0.49538481], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.44574717], dtype=float32),
#   'logits': array([-0.21786904], dtype=float32),
#   'probabilities': array([ 0.55425286,  0.4457472 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13100883], dtype=float32),
#   'logits': array([-1.89206815], dtype=float32),
#   'probabilities': array([ 0.86899114,  0.13100883], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35388058], dtype=float32),
#   'logits': array([-0.60202491], dtype=float32),
#   'probabilities': array([ 0.64611942,  0.35388055], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.67001045], dtype=float32),
#   'logits': array([ 0.70823228], dtype=float32),
#   'probabilities': array([ 0.32998955,  0.67001045], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50337636], dtype=float32),
#   'logits': array([ 0.0135057], dtype=float32),
#   'probabilities': array([ 0.49662361,  0.50337636], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35378796], dtype=float32),
#   'logits': array([-0.60243005], dtype=float32),
#   'probabilities': array([ 0.64621204,  0.35378793], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54673576], dtype=float32),
#   'logits': array([ 0.18749022], dtype=float32),
#   'probabilities': array([ 0.45326427,  0.54673576], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20273739], dtype=float32),
#   'logits': array([-1.36927271], dtype=float32),
#   'probabilities': array([ 0.79726267,  0.20273739], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18397629], dtype=float32),
#   'logits': array([-1.48963654], dtype=float32),
#   'probabilities': array([ 0.81602371,  0.18397629], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1263063], dtype=float32),
#   'logits': array([-1.93402004], dtype=float32),
#   'probabilities': array([ 0.87369376,  0.1263063 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25514179], dtype=float32),
#   'logits': array([-1.07137442], dtype=float32),
#   'probabilities': array([ 0.74485821,  0.25514179], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.44468656], dtype=float32),
#   'logits': array([-0.2221632], dtype=float32),
#   'probabilities': array([ 0.55531353,  0.44468656], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.67249918], dtype=float32),
#   'logits': array([ 0.7195102], dtype=float32),
#   'probabilities': array([ 0.32750085,  0.67249918], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21871312], dtype=float32),
#   'logits': array([-1.27318144], dtype=float32),
#   'probabilities': array([ 0.78128684,  0.21871312], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15039892], dtype=float32),
#   'logits': array([-1.73147571], dtype=float32),
#   'probabilities': array([ 0.84960109,  0.15039892], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37351683], dtype=float32),
#   'logits': array([-0.51715899], dtype=float32),
#   'probabilities': array([ 0.62648326,  0.37351683], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22181264], dtype=float32),
#   'logits': array([-1.25513434], dtype=float32),
#   'probabilities': array([ 0.77818739,  0.22181262], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13635935], dtype=float32),
#   'logits': array([-1.8458631], dtype=float32),
#   'probabilities': array([ 0.86364067,  0.13635935], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17172082], dtype=float32),
#   'logits': array([-1.57348025], dtype=float32),
#   'probabilities': array([ 0.8282792 ,  0.17172082], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11479989], dtype=float32),
#   'logits': array([-2.04262328], dtype=float32),
#   'probabilities': array([ 0.88520014,  0.11479989], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39394984], dtype=float32),
#   'logits': array([-0.43073916], dtype=float32),
#   'probabilities': array([ 0.60605013,  0.39394984], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.76481968], dtype=float32),
#   'logits': array([ 1.17928767], dtype=float32),
#   'probabilities': array([ 0.2351803 ,  0.76481968], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.75025803], dtype=float32),
#   'logits': array([ 1.09998894], dtype=float32),
#   'probabilities': array([ 0.24974197,  0.75025803], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5179494], dtype=float32),
#   'logits': array([ 0.07182848], dtype=float32),
#   'probabilities': array([ 0.4820506,  0.5179494], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.45090681], dtype=float32),
#   'logits': array([-0.19700754], dtype=float32),
#   'probabilities': array([ 0.54909325,  0.45090684], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52628344], dtype=float32),
#   'logits': array([ 0.10523093], dtype=float32),
#   'probabilities': array([ 0.47371647,  0.52628344], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10584783], dtype=float32),
#   'logits': array([-2.13387346], dtype=float32),
#   'probabilities': array([ 0.8941521 ,  0.10584782], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49043873], dtype=float32),
#   'logits': array([-0.03824985], dtype=float32),
#   'probabilities': array([ 0.5095613,  0.4904387], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.75644588], dtype=float32),
#   'logits': array([ 1.13329196], dtype=float32),
#   'probabilities': array([ 0.24355409,  0.75644588], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38289607], dtype=float32),
#   'logits': array([-0.47727394], dtype=float32),
#   'probabilities': array([ 0.61710393,  0.38289607], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26077205], dtype=float32),
#   'logits': array([-1.04195976], dtype=float32),
#   'probabilities': array([ 0.73922795,  0.26077202], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32199007], dtype=float32),
#   'logits': array([-0.7446413], dtype=float32),
#   'probabilities': array([ 0.67800993,  0.32199004], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55914921], dtype=float32),
#   'logits': array([ 0.23770988], dtype=float32),
#   'probabilities': array([ 0.44085079,  0.55914921], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2272771], dtype=float32),
#   'logits': array([-1.22375047], dtype=float32),
#   'probabilities': array([ 0.7727229 ,  0.22727711], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61322218], dtype=float32),
#   'logits': array([ 0.46087694], dtype=float32),
#   'probabilities': array([ 0.38677779,  0.61322218], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3666954], dtype=float32),
#   'logits': array([-0.54641986], dtype=float32),
#   'probabilities': array([ 0.6333046 ,  0.36669543], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37249982], dtype=float32),
#   'logits': array([-0.52150738], dtype=float32),
#   'probabilities': array([ 0.62750018,  0.37249982], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15071498], dtype=float32),
#   'logits': array([-1.72900438], dtype=float32),
#   'probabilities': array([ 0.84928501,  0.15071496], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18404886], dtype=float32),
#   'logits': array([-1.48915315], dtype=float32),
#   'probabilities': array([ 0.81595117,  0.18404888], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17355868], dtype=float32),
#   'logits': array([-1.56061316], dtype=float32),
#   'probabilities': array([ 0.82644129,  0.17355867], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39692718], dtype=float32),
#   'logits': array([-0.41828525], dtype=float32),
#   'probabilities': array([ 0.60307282,  0.39692712], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14019339], dtype=float32),
#   'logits': array([-1.8136847], dtype=float32),
#   'probabilities': array([ 0.85980666,  0.14019339], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.72996378], dtype=float32),
#   'logits': array([ 0.99443865], dtype=float32),
#   'probabilities': array([ 0.27003625,  0.72996378], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19300957], dtype=float32),
#   'logits': array([-1.43057203], dtype=float32),
#   'probabilities': array([ 0.80699039,  0.19300956], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.47806597], dtype=float32),
#   'logits': array([-0.08779263], dtype=float32),
#   'probabilities': array([ 0.52193409,  0.47806594], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14509407], dtype=float32),
#   'logits': array([-1.77360916], dtype=float32),
#   'probabilities': array([ 0.8549059 ,  0.14509407], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.65785283], dtype=float32),
#   'logits': array([ 0.65374053], dtype=float32),
#   'probabilities': array([ 0.34214711,  0.65785283], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30168214], dtype=float32),
#   'logits': array([-0.83930045], dtype=float32),
#   'probabilities': array([ 0.69831789,  0.30168214], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18408009], dtype=float32),
#   'logits': array([-1.48894525], dtype=float32),
#   'probabilities': array([ 0.81591994,  0.18408009], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30405173], dtype=float32),
#   'logits': array([-0.82807744], dtype=float32),
#   'probabilities': array([ 0.69594824,  0.30405173], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32339442], dtype=float32),
#   'logits': array([-0.7382158], dtype=float32),
#   'probabilities': array([ 0.67660558,  0.32339442], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15687469], dtype=float32),
#   'logits': array([-1.68166828], dtype=float32),
#   'probabilities': array([ 0.84312534,  0.1568747 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.70080507], dtype=float32),
#   'logits': array([ 0.85113454], dtype=float32),
#   'probabilities': array([ 0.2991949 ,  0.70080507], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18328041], dtype=float32),
#   'logits': array([-1.49427855], dtype=float32),
#   'probabilities': array([ 0.81671959,  0.18328041], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16276795], dtype=float32),
#   'logits': array([-1.63777578], dtype=float32),
#   'probabilities': array([ 0.83723205,  0.16276795], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22773318], dtype=float32),
#   'logits': array([-1.22115552], dtype=float32),
#   'probabilities': array([ 0.77226686,  0.22773317], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.4090983], dtype=float32),
#   'logits': array([-0.36769414], dtype=float32),
#   'probabilities': array([ 0.59090167,  0.40909833], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25181028], dtype=float32),
#   'logits': array([-1.08898067], dtype=float32),
#   'probabilities': array([ 0.74818969,  0.25181025], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10965709], dtype=float32),
#   'logits': array([-2.09424853], dtype=float32),
#   'probabilities': array([ 0.89034289,  0.10965709], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.82112032], dtype=float32),
#   'logits': array([ 1.5239563], dtype=float32),
#   'probabilities': array([ 0.17887966,  0.82112032], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.65657371], dtype=float32),
#   'logits': array([ 0.64806235], dtype=float32),
#   'probabilities': array([ 0.34342632,  0.65657371], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49770308], dtype=float32),
#   'logits': array([-0.00918794], dtype=float32),
#   'probabilities': array([ 0.50229698,  0.49770305], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.71302062], dtype=float32),
#   'logits': array([ 0.91009998], dtype=float32),
#   'probabilities': array([ 0.28697938,  0.71302062], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10788467], dtype=float32),
#   'logits': array([-2.11253262], dtype=float32),
#   'probabilities': array([ 0.89211535,  0.10788468], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13782495], dtype=float32),
#   'logits': array([-1.83347392], dtype=float32),
#   'probabilities': array([ 0.86217505,  0.13782495], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20054153], dtype=float32),
#   'logits': array([-1.38291323], dtype=float32),
#   'probabilities': array([ 0.79945844,  0.20054153], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32210019], dtype=float32),
#   'logits': array([-0.74413687], dtype=float32),
#   'probabilities': array([ 0.67789978,  0.32210016], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.36456513], dtype=float32),
#   'logits': array([-0.55560434], dtype=float32),
#   'probabilities': array([ 0.63543487,  0.36456516], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55084562], dtype=float32),
#   'logits': array([ 0.20408785], dtype=float32),
#   'probabilities': array([ 0.44915441,  0.55084562], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51165634], dtype=float32),
#   'logits': array([ 0.04663384], dtype=float32),
#   'probabilities': array([ 0.48834363,  0.51165634], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34660488], dtype=float32),
#   'logits': array([-0.63399643], dtype=float32),
#   'probabilities': array([ 0.65339512,  0.34660491], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32094342], dtype=float32),
#   'logits': array([-0.7494396], dtype=float32),
#   'probabilities': array([ 0.67905658,  0.32094342], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3209801], dtype=float32),
#   'logits': array([-0.74927133], dtype=float32),
#   'probabilities': array([ 0.67901993,  0.3209801 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17692344], dtype=float32),
#   'logits': array([-1.53733218], dtype=float32),
#   'probabilities': array([ 0.82307661,  0.17692344], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61902308], dtype=float32),
#   'logits': array([ 0.48540378], dtype=float32),
#   'probabilities': array([ 0.38097692,  0.61902308], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1175089], dtype=float32),
#   'logits': array([-2.01623464], dtype=float32),
#   'probabilities': array([ 0.88249105,  0.11750889], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21192783], dtype=float32),
#   'logits': array([-1.31334388], dtype=float32),
#   'probabilities': array([ 0.78807217,  0.21192783], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52680814], dtype=float32),
#   'logits': array([ 0.10733557], dtype=float32),
#   'probabilities': array([ 0.47319183,  0.52680814], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34553543], dtype=float32),
#   'logits': array([-0.6387223], dtype=float32),
#   'probabilities': array([ 0.6544646 ,  0.34553543], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18270172], dtype=float32),
#   'logits': array([-1.49814916], dtype=float32),
#   'probabilities': array([ 0.81729829,  0.18270174], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2694031], dtype=float32),
#   'logits': array([-0.99765313], dtype=float32),
#   'probabilities': array([ 0.73059684,  0.26940307], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25362018], dtype=float32),
#   'logits': array([-1.07939684], dtype=float32),
#   'probabilities': array([ 0.74637985,  0.25362018], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12651868], dtype=float32),
#   'logits': array([-1.93209672], dtype=float32),
#   'probabilities': array([ 0.87348133,  0.1265187 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18561564], dtype=float32),
#   'logits': array([-1.47875428], dtype=float32),
#   'probabilities': array([ 0.81438434,  0.18561566], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54193902], dtype=float32),
#   'logits': array([ 0.16815114], dtype=float32),
#   'probabilities': array([ 0.45806098,  0.54193902], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.67829502], dtype=float32),
#   'logits': array([ 0.74594736], dtype=float32),
#   'probabilities': array([ 0.32170498,  0.67829502], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.58585906], dtype=float32),
#   'logits': array([ 0.34687281], dtype=float32),
#   'probabilities': array([ 0.41414097,  0.58585906], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.68988121], dtype=float32),
#   'logits': array([ 0.79956412], dtype=float32),
#   'probabilities': array([ 0.31011873,  0.68988121], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.40422148], dtype=float32),
#   'logits': array([-0.38790596], dtype=float32),
#   'probabilities': array([ 0.59577852,  0.40422153], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25647959], dtype=float32),
#   'logits': array([-1.06434715], dtype=float32),
#   'probabilities': array([ 0.74352038,  0.25647959], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.46793512], dtype=float32),
#   'logits': array([-0.12843585], dtype=float32),
#   'probabilities': array([ 0.53206491,  0.46793512], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17651699], dtype=float32),
#   'logits': array([-1.54012573], dtype=float32),
#   'probabilities': array([ 0.82348299,  0.17651701], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14019799], dtype=float32),
#   'logits': array([-1.81364644], dtype=float32),
#   'probabilities': array([ 0.85980195,  0.14019799], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17451529], dtype=float32),
#   'logits': array([-1.55395842], dtype=float32),
#   'probabilities': array([ 0.82548475,  0.17451529], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.46316442], dtype=float32),
#   'logits': array([-0.14760983], dtype=float32),
#   'probabilities': array([ 0.53683561,  0.46316442], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.05326769], dtype=float32),
#   'logits': array([-2.8776865], dtype=float32),
#   'probabilities': array([ 0.94673234,  0.05326769], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26266801], dtype=float32),
#   'logits': array([-1.03214729], dtype=float32),
#   'probabilities': array([ 0.73733199,  0.26266801], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15789011], dtype=float32),
#   'logits': array([-1.67401123], dtype=float32),
#   'probabilities': array([ 0.84210992,  0.15789011], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2270043], dtype=float32),
#   'logits': array([-1.2253046], dtype=float32),
#   'probabilities': array([ 0.77299571,  0.22700429], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23888165], dtype=float32),
#   'logits': array([-1.15882063], dtype=float32),
#   'probabilities': array([ 0.76111835,  0.23888166], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26655391], dtype=float32),
#   'logits': array([-1.01217759], dtype=float32),
#   'probabilities': array([ 0.73344612,  0.26655391], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.74907857], dtype=float32),
#   'logits': array([ 1.09370399], dtype=float32),
#   'probabilities': array([ 0.25092143,  0.74907857], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16673489], dtype=float32),
#   'logits': array([-1.6089468], dtype=float32),
#   'probabilities': array([ 0.83326507,  0.16673487], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11657318], dtype=float32),
#   'logits': array([-2.0252893], dtype=float32),
#   'probabilities': array([ 0.88342685,  0.11657318], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57040668], dtype=float32),
#   'logits': array([ 0.28351057], dtype=float32),
#   'probabilities': array([ 0.42959332,  0.57040668], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.4318096], dtype=float32),
#   'logits': array([-0.27447188], dtype=float32),
#   'probabilities': array([ 0.5681904,  0.4318096], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.84129941], dtype=float32),
#   'logits': array([ 1.66792822], dtype=float32),
#   'probabilities': array([ 0.1587006 ,  0.84129941], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59613508], dtype=float32),
#   'logits': array([ 0.38938689], dtype=float32),
#   'probabilities': array([ 0.40386489,  0.59613508], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11772131], dtype=float32),
#   'logits': array([-2.01418781], dtype=float32),
#   'probabilities': array([ 0.88227868,  0.11772132], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61645955], dtype=float32),
#   'logits': array([ 0.47454774], dtype=float32),
#   'probabilities': array([ 0.38354042,  0.61645955], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50812894], dtype=float32),
#   'logits': array([ 0.03251863], dtype=float32),
#   'probabilities': array([ 0.49187106,  0.50812894], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.74982876], dtype=float32),
#   'logits': array([ 1.09769917], dtype=float32),
#   'probabilities': array([ 0.25017124,  0.74982876], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22152154], dtype=float32),
#   'logits': array([-1.25682151], dtype=float32),
#   'probabilities': array([ 0.77847844,  0.22152153], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16144285], dtype=float32),
#   'logits': array([-1.64753163], dtype=float32),
#   'probabilities': array([ 0.83855718,  0.16144285], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52941155], dtype=float32),
#   'logits': array([ 0.11778224], dtype=float32),
#   'probabilities': array([ 0.47058842,  0.52941155], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14378397], dtype=float32),
#   'logits': array([-1.7842108], dtype=float32),
#   'probabilities': array([ 0.85621601,  0.14378396], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.76792783], dtype=float32),
#   'logits': array([ 1.19664741], dtype=float32),
#   'probabilities': array([ 0.23207214,  0.76792783], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50592482], dtype=float32),
#   'logits': array([ 0.02370048], dtype=float32),
#   'probabilities': array([ 0.49407515,  0.50592482], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16353618], dtype=float32),
#   'logits': array([-1.63214898], dtype=float32),
#   'probabilities': array([ 0.83646381,  0.16353619], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52593422], dtype=float32),
#   'logits': array([ 0.10383022], dtype=float32),
#   'probabilities': array([ 0.47406572,  0.52593422], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.42691615], dtype=float32),
#   'logits': array([-0.29444438], dtype=float32),
#   'probabilities': array([ 0.57308382,  0.42691615], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10116638], dtype=float32),
#   'logits': array([-2.18433142], dtype=float32),
#   'probabilities': array([ 0.89883357,  0.10116637], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.48948535], dtype=float32),
#   'logits': array([-0.04206467], dtype=float32),
#   'probabilities': array([ 0.51051462,  0.48948538], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57558471], dtype=float32),
#   'logits': array([ 0.30467391], dtype=float32),
#   'probabilities': array([ 0.42441535,  0.57558471], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.7324025], dtype=float32),
#   'logits': array([ 1.00684619], dtype=float32),
#   'probabilities': array([ 0.26759753,  0.7324025 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.8029539], dtype=float32),
#   'logits': array([ 1.40485978], dtype=float32),
#   'probabilities': array([ 0.19704606,  0.8029539 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3882997], dtype=float32),
#   'logits': array([-0.45446503], dtype=float32),
#   'probabilities': array([ 0.6117003 ,  0.38829967], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15029389], dtype=float32),
#   'logits': array([-1.7322979], dtype=float32),
#   'probabilities': array([ 0.84970611,  0.15029389], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.07619532], dtype=float32),
#   'logits': array([-2.49520063], dtype=float32),
#   'probabilities': array([ 0.92380464,  0.07619531], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10043979], dtype=float32),
#   'logits': array([-2.19234753], dtype=float32),
#   'probabilities': array([ 0.89956027,  0.10043979], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.249542], dtype=float32),
#   'logits': array([-1.10105646], dtype=float32),
#   'probabilities': array([ 0.75045806,  0.24954201], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30674872], dtype=float32),
#   'logits': array([-0.81536365], dtype=float32),
#   'probabilities': array([ 0.69325125,  0.30674869], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.27225283], dtype=float32),
#   'logits': array([-0.9832226], dtype=float32),
#   'probabilities': array([ 0.7277472,  0.2722528], dtype=float32)}]

# %% [markdown]
# # DNN Classifier

# %% [markdown]
# ### group for DNN need to use embedded group column

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=len(group_names))
feat_cols[7] = embedded_group_column

# %% [markdown]
# ### 1. Train

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sr/9k0jqkfs33q22ppyt_t7yjt9716826/T/tmpg7yb0vbk
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_tf_random_seed': 1, '_save_checkpoints_steps': None, '_log_step_count_steps': 100, '_session_config': None, '_model_dir': '/var/folders/sr/9k0jqkfs33q22ppyt_t7yjt9716826/T/tmpg7yb0vbk', '_keep_checkpoint_max': 5, '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sr/9k0jqkfs33q22ppyt_t7yjt9716826/T/tmpg7yb0vbk/model.ckpt.
# INFO:tensorflow:step = 1, loss = 7.68058
# INFO:tensorflow:global_step/sec: 461.293
# INFO:tensorflow:step = 101, loss = 5.73614 (0.218 sec)
# INFO:tensorflow:global_step/sec: 490.987
# INFO:tensorflow:step = 201, loss = 6.75528 (0.204 sec)
# INFO:tensorflow:global_step/sec: 486.1
# INFO:tensorflow:step = 301, loss = 8.84192 (0.206 sec)
# INFO:tensorflow:global_step/sec: 463.478
# INFO:tensorflow:step = 401, loss = 8.25577 (0.216 sec)
# INFO:tensorflow:global_step/sec: 473.167
# INFO:tensorflow:step = 501, loss = 2.92929 (0.211 sec)
# INFO:tensorflow:global_step/sec: 480.243
# INFO:tensorflow:step = 601, loss = 3.38454 (0.208 sec)
# INFO:tensorflow:global_step/sec: 449.299
# INFO:tensorflow:step = 701, loss = 2.19354 (0.223 sec)
# INFO:tensorflow:global_step/sec: 467.791
# INFO:tensorflow:step = 801, loss = 4.8264 (0.214 sec)
# INFO:tensorflow:global_step/sec: 487.893
# INFO:tensorflow:step = 901, loss = 2.72556 (0.205 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/sr/9k0jqkfs33q22ppyt_t7yjt9716826/T/tmpg7yb0vbk/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.82385.

# %% [markdown]
# ### 2. Evaluate [Test]

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,y=y_test,batch_size=10,num_epochs=1,shuffle=False)
dnn_model.evaluate(eval_input_func)
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-03-17-22:04:59
# INFO:tensorflow:Restoring parameters from /var/folders/sr/9k0jqkfs33q22ppyt_t7yjt9716826/T/tmpg7yb0vbk/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2018-03-17-22:05:00
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.732283, accuracy_baseline = 0.65748, auc = 0.817124, auc_precision_recall = 0.659474, average_loss = 0.502486, global_step = 1000, label/mean = 0.34252, loss = 127.631, prediction/mean = 0.354419
# {'accuracy': 0.73228347,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.81712437,
#  'auc_precision_recall': 0.65947431,
#  'average_loss': 0.50248593,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 127.63143,
#  'prediction/mean': 0.35441881}
